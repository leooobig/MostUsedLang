# %% [markdown]
# ## Conhecendo a requests

# %% [markdown]
# ### Primeira requisição

# %%
import requests
import os
from dotenv import load_dotenv

# %%
r = requests.get('https://api.github.com/events')

# %%
r
# Out:
# <Response [200]>

# %% [markdown]
# ### Explorando a biblioteca

# %%
r.status_code
# Out:
# 200

# %%
r.url
# Out:
# 'https://api.github.com/events'

# %%
r.text
# Out:
# '[{"id":"46467489089","type":"PushEvent","actor":{"id":77738923,"login":"atyrell3","display_login":"atyrell3","gravatar_id":"","url":"https://api.github.com/users/atyrell3","avatar_url":"https://avatars.githubusercontent.com/u/77738923?"},"repo":{"id":708950142,"name":"ScottLarge-NOAA/bsb","url":"https://api.github.com/repos/ScottLarge-NOAA/bsb"},"payload":{"repository_id":708950142,"push_id":22602684104,"size":2,"distinct_size":2,"ref":"refs/heads/main","head":"1d3c3cdce939936ce2d96b0317545f1c001c9d23","before":"b415832f5161de5e514d4c5bbd3416ced3c1d8c7","commits":[{"sha":"b82f115909428ee3a0ae37ab3ef0ba19f5e7da9e","author":{"email":"abigail.tyrell@noaa.gov","name":"atyrell3"},"message":"figure updates","distinct":true,"url":"https://api.github.com/repos/ScottLarge-NOAA/bsb/commits/b82f115909428ee3a0ae37ab3ef0ba19f5e7da9e"},{"sha":"1d3c3cdce939936ce2d96b0317545f1c001c9d23","author":{"email":"77738923+atyrell3@users.noreply.github.com","name":"atyrell3"},"message":"Merge branch \'main\' of https://github.com/ScottLarge-NOAA/bsb\\nmerge changes","distinct":true,"url":"https://api.github.com/repos/ScottLarge-NOAA/bsb/commits/1d3c3cdce939936ce2d96b0317545f1c001c9d23"}]},"public":true,"created_at":"2025-02-11T20:54:54Z"},{"id":"46467489099","type":"CreateEvent","actor":{"id":180904546,"login":"stefan-r-huber","display_login":"stefan-r-huber","gravatar_id":"","url":"https://api.github.com/users/stefan-r-huber","avatar_url":"https://avatars.githubusercontent.com/u/180904546?"},"repo":{"id":931176656,"name":"stefan-r-huber/607_SS25","url":"https://api.github.com/repos/stefan-r-huber/607_SS25"},"payload":{"ref":"main","ref_type":"branch","master_branch":"main","description":"Spring 2025 Semester","pusher_type":"user"},"public":true,"created_at":"2025-02-11T20:54:54Z"},{"id":"46467489027","type":"PushEvent","actor":{"id":41898282,"login":"github-actions[bot]","display_login":"github-actions","gravatar_id":"","url":"https://api.github.com/users/github-actions[bot]","avatar_url":"https://avatars.githubusercontent.com/u/41898282?"},"repo":{"id":930796288,"name":"tranyiawqilong/automatic-eureka","url":"https://api.github.com/repos/tranyiawqilong/automatic-eureka"},"payload":{"repository_id":930796288,"push_id":22602683986,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"a8c867719ac8df6be2d68d4e58648cd85781e98f","before":"e4fd51e522cdbfec99388fc9cb547f5d29e50161","commits":[{"sha":"a8c867719ac8df6be2d68d4e58648cd85781e98f","author":{"email":"qilong711@mail.com","name":"tranyiawqilong"},"message":"2023-06-15T20:54:49+00:00","distinct":true,"url":"https://api.github.com/repos/tranyiawqilong/automatic-eureka/commits/a8c867719ac8df6be2d68d4e58648cd85781e98f"}]},"public":true,"created_at":"2025-02-11T20:54:54Z"},{"id":"46467489090","type":"CreateEvent","actor":{"id":39066999,"login":"josecorella","display_login":"josecorella","gravatar_id":"","url":"https://api.github.com/users/josecorella","avatar_url":"https://avatars.githubusercontent.com/u/39066999?"},"repo":{"id":666125685,"name":"aws/aws-cryptographic-material-providers-library","url":"https://api.github.com/repos/aws/aws-cryptographic-material-providers-library"},"payload":{"ref":"v1.10.0","ref_type":"tag","master_branch":"main","description":"AWS Cryptographic Material Providers Library","pusher_type":"user"},"public":true,"created_at":"2025-02-11T20:54:54Z","org":{"id":2232217,"login":"aws","gravatar_id":"","url":"https://api.github.com/orgs/aws","avatar_url":"https://avatars.githubusercontent.com/u/2232217?"}},{"id":"46467489082","type":"IssueCommentEvent","actor":{"id":22429695,"login":"codecov[bot]","display_login":"codecov","gravatar_id":"","url":"https://api.github.com/users/codecov[bot]","avatar_url":"https://avatars.githubusercontent.com/u/22429695?"},"repo":{"id":679553008,"name":"partcad/partcad","url":"https://api.github.com/repos/partcad/partcad"},"payload":{"action":"created","issue":{"url":"https://api.github.com/repos/partcad/partcad/issues/361","repository_url":"h ...

# %%
r.json()
# Out:
# [{'id': '46467489089',
#   'type': 'PushEvent',
#   'actor': {'id': 77738923,
#    'login': 'atyrell3',
#    'display_login': 'atyrell3',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/atyrell3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/77738923?'},
#   'repo': {'id': 708950142,
#    'name': 'ScottLarge-NOAA/bsb',
#    'url': 'https://api.github.com/repos/ScottLarge-NOAA/bsb'},
#   'payload': {'repository_id': 708950142,
#    'push_id': 22602684104,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/main',
#    'head': '1d3c3cdce939936ce2d96b0317545f1c001c9d23',
#    'before': 'b415832f5161de5e514d4c5bbd3416ced3c1d8c7',
#    'commits': [{'sha': 'b82f115909428ee3a0ae37ab3ef0ba19f5e7da9e',
#      'author': {'email': 'abigail.tyrell@noaa.gov', 'name': 'atyrell3'},
#      'message': 'figure updates',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ScottLarge-NOAA/bsb/commits/b82f115909428ee3a0ae37ab3ef0ba19f5e7da9e'},
#     {'sha': '1d3c3cdce939936ce2d96b0317545f1c001c9d23',
#      'author': {'email': '77738923+atyrell3@users.noreply.github.com',
#       'name': 'atyrell3'},
#      'message': "Merge branch 'main' of https://github.com/ScottLarge-NOAA/bsb\nmerge changes",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ScottLarge-NOAA/bsb/commits/1d3c3cdce939936ce2d96b0317545f1c001c9d23'}]},
#   'public': True,
#   'created_at': '2025-02-11T20:54:54Z'},
#  {'id': '46467489099',
#   'type': 'CreateEvent',
#   'actor': {'id': 180904546,
#    'login': 'stefan-r-huber',
#    'display_login': 'stefan-r-huber',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/stefan-r-huber',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/180904546?'},
#   'repo': {'id': 931176656,
#    'name': 'stefan-r-huber/607_SS25',
#    'url': 'https://api.github.com/repos/stefan-r-huber/607_SS25'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': 'Spring 2025 Semester',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2025-02-11T20:54:54Z'},
#  {'id': '46467489027',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 930796288,
#    'name': 'tranyiawqilong/automatic-eureka',
#    'url': 'https://api.github.com/repos/tranyiawqilong/automatic-eureka'},
#   'payload': {'repository_id': 930796288,
#    'push_id': 22602683986,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'a8c867719ac8df6be2d68d4e58648cd85781e98f',
#    'before': 'e4fd51e522cdbfec99388fc9cb547f5d29e50161',
#    'commits': [{'sha': 'a8c867719ac8df6be2d68d4e58648cd85781e98f',
#      'author': {'email': 'qilong711@mail.com', 'name': 'tranyiawqilong'},
#      'message': '2023-06-15T20:54:49+00:00',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/tranyiawqilong/automatic-eureka/commits/a8c867719ac8df6be2d68d4e58648cd85781e98f'}]},
#   'public': True,
#   'created_at': '2025-02-11T20:54:54Z'},
#  {'id': '46467489090',
#   'type': 'CreateEvent',
#   'actor': {'id': 39066999,
#    'login': 'josecorella',
#    'display_login': 'josecorella',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/josecorella',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39066999?'},
#   'repo': {'id': 666125685,
#    'name': 'aws/aws-cryptographic-material-providers-library',
#    'url': 'https://api.github.com/repos/aws/aws-cryptographic-material-providers-library'},
#   'payload': {'ref': 'v1.10.0',
#    'ref_type': 'tag',
#    'master_branch': 'main',
#    'description': 'AWS Cryptographic Material Providers Library',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2025-02-11T20:54:54Z',
#   'org': {'id': 2232217,
#    'login': 'aws',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/aws',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2232217?'}},
#  {'id': '46467489082',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 22429695,
#    'login': 'codecov[bot]',
#    'display_login': 'codecov',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/codecov[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22429695?'},
#   'repo': {'id': 679553008,
#    'name': 'partcad/partcad',
#    'url': 'https://api.github.com/repos/partcad/partcad'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/partcad/partcad/issues/361',
#     'repository_url': 'https://api.github.com/repos/partcad/partcad',
#     'labels_url': 'https://api.github.com/repos/partcad/partcad/issues/361/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/partcad/partcad/issues/361/comments',
#     'events_url': 'https://api.github.com/repos/partcad/partcad/issues/361/events',
#     'html_url': 'https://github.com/partcad/partcad/pull/361',
#     'id': 2846484042,
#     'node_id': 'PR_kwDOKIEn8M6K3Lno',
#     'number': 361,
#     'title': 'Updated the README docs',
#     'user': {'login': 'clairbee',
#      'id': 7663232,
#      'node_id': 'MDQ6VXNlcjc2NjMyMzI=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/7663232?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/clairbee',
#      'html_url': 'https://github.com/clairbee',
#      'followers_url': 'https://api.github.com/users/clairbee/followers',
#      'following_url': 'https://api.github.com/users/clairbee/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/clairbee/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/clairbee/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/clairbee/subscriptions',
#      'organizations_url': 'https://api.github.com/users/clairbee/orgs',
#      'repos_url': 'https://api.github.com/users/clairbee/repos',
#      'events_url': 'https://api.github.com/users/clairbee/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/clairbee/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': {'login': 'clairbee',
#      'id': 7663232,
#      'node_id': 'MDQ6VXNlcjc2NjMyMzI=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/7663232?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/clairbee',
#      'html_url': 'https://github.com/clairbee',
#      'followers_url': 'https://api.github.com/users/clairbee/followers',
#      'following_url': 'https://api.github.com/users/clairbee/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/clairbee/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/clairbee/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/clairbee/subscriptions',
#      'organizations_url': 'https://api.github.com/users/clairbee/orgs',
#      'repos_url': 'https://api.github.com/users/clairbee/repos',
#      'events_url': 'https://api.github.com/users/clairbee/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/clairbee/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'assignees': [{'login': 'clairbee',
#       'id': 7663232,
#       'node_id': 'MDQ6VXNlcjc2NjMyMzI=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/7663232?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/clairbee',
#       'html_url': 'https://github.com/clairbee',
#       'followers_url': 'https://api.github.com/users/clairbee/followers',
#       'following_url': 'https://api.github.com/users/clairbee/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/clairbee/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/clairbee/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/clairbee/subscriptions',
#       'organizations_url': 'https://api.github.com/users/clairbee/orgs',
#       'repos_url': 'https://api.github.com/users/clairbee/repos',
#       'events_url': 'https://api.github.com/users/clairbee/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/clairbee/received_events',
#       'type': 'User',
#       'user_view_type': 'public',
#       'site_admin': False}],
#     'milestone': None,
#     'comments': 2,
#     'created_at': '2025-02-11T20:51:37Z',
#     'updated_at': '2025-02-11T20:54:54Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0},
#     'active_lock_reason': None,
#     'draft': False,
#     'pull_request': {'url': 'https://api.github.com/repos/partcad/partcad/pulls/361',
#      'html_url': 'https://github.com/partcad/partcad/pull/361',
#      'diff_url': 'https://github.com/partcad/partcad/pull/361.diff',
#      'patch_url': 'https://github.com/partcad/partcad/pull/361.patch',
#      'merged_at': None},
#     'body': '## Copilot Summary\r\n\r\n<!-- Use GitHub Copilot to generate a summary of your changes here. -->\r\n\r\n<!--\r\n\r\nCodeRabbit will automatically analyze your PR and provide:\r\n- Code review comments\r\n- Security analysis\r\n- Performance insights\r\nNo action needed in this section - let AI do the heavy lifting!\r\n\r\n@coderabbitai\r\n-->\r\n',
#     'reactions': {'url': 'https://api.github.com/repos/partcad/partcad/issues/361/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/partcad/partcad/issues/361/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None},
#    'comment': {'url': 'https://api.github.com/repos/partcad/partcad/issues/comments/2652046061',
#     'html_url': 'https://github.com/partcad/partcad/pull/361#issuecomment-2652046061',
#     'issue_url': 'https://api.github.com/repos/partcad/partcad/issues/361',
#     'id': 2652046061,
#     'node_id': 'IC_kwDOKIEn8M6eEwLt',
#     'user': {'login': 'codecov[bot]',
#      'id': 22429695,
#      'node_id': 'MDM6Qm90MjI0Mjk2OTU=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/254?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/codecov%5Bbot%5D',
#      'html_url': 'https://github.com/apps/codecov',
#      'followers_url': 'https://api.github.com/users/codecov%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/codecov%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/codecov%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/codecov%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/codecov%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/codecov%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/codecov%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/codecov%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/codecov%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'created_at': '2025-02-11T20:54:53Z',
#     'updated_at': '2025-02-11T20:54:53Z',
#     'author_association': 'NONE',
#     'body': '## [Codecov](https://app.codecov.io/gh/partcad/partcad/pull/361?dropdown=coverage&src=pr&el=h1&utm_medium=referral&utm_source=github&utm_content=comment&utm_campaign=pr+comments&utm_term=partcad) Report\nAll modified and coverable lines are covered by tests :white_check_mark:\n\n| [Files with missing lines](https://app.codecov.io/gh/partcad/partcad/pull/361?dropdown=coverage&src=pr&el=tree&utm_medium=referral&utm_source=github&utm_content=comment&utm_campaign=pr+comments&utm_term=partcad) | Coverage Δ | |\n|---|---|---|\n| [partcad/src/partcad/project\\_factory\\_local.py](https://app.codecov.io/gh/partcad/partcad/pull/361?src=pr&el=tree&filepath=partcad%2Fsrc%2Fpartcad%2Fproject_factory_local.py&utm_medium=referral&utm_source=github&utm_content=comment&utm_campaign=pr+comments&utm_term=partcad#diff-cGFydGNhZC9zcmMvcGFydGNhZC9wcm9qZWN0X2ZhY3RvcnlfbG9jYWwucHk=) | `88.23% <ø> (-5.89%)` | :arrow_down: |\n\n... and [117 files with indirect coverage changes](https://app.codecov.io/gh/partcad/partcad/pull/361/indirect-changes?src=pr&el=tree-more&utm_medium=referral&utm_source=github&utm_content=comment&utm_campaign=pr+comments&utm_term=partcad)\n',
#     'reactions': {'url': 'https://api.github.com/repos/partcad/partcad/issues/comments/2652046061/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': {'id': 254,
#      'client_id': 'Iv1.9d88ef6ecc903626',
#      'slug': 'codecov',
#      'node_id': 'MDM6QXBwMjU0',
#      'owner': {'login': 'codecov',
#       'id': 8226205,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjgyMjYyMDU=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/8226205?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/codecov',
#       'html_url': 'https://github.com/codecov',
#       'followers_url': 'https://api.github.com/users/codecov/followers',
#       'following_url': 'https://api.github.com/users/codecov/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/codecov/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/codecov/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/codecov/subscriptions',
#       'organizations_url': 'https://api.github.com/users/codecov/orgs',
#       'repos_url': 'https://api.github.com/users/codecov/repos',
#       'events_url': 'https://api.github.com/users/codecov/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/codecov/received_events',
#       'type': 'Organization',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'name': 'Codecov',
#      'description': "Codecov provides highly integrated tools to group, merge, archive and compare coverage reports. Whether your team is comparing changes in a pull request or reviewing a single commit, Codecov will improve the code review workflow and quality.\r\n\r\n## Code coverage done right.®\r\n\r\n1. Upload coverage reports from your CI builds.\r\n2. Codecov merges all builds and languages into one beautiful coherent report.\r\n3. Get commit statuses, pull request comments and coverage overlay via our browser extension.\r\n\r\nWhen Codecov merges your uploads it keeps track of the CI provider (inc. build details) and user specified context, e.g. `#unittest` ~ `#smoketest` or `#oldcode` ~ `#newcode`. You can track the `#unittest` coverage independently of other groups. [Learn more here](\r\nhttp://docs.codecov.io/docs/flags)\r\n\r\nThrough **Codecov's Browser Extension** reports overlay directly in GitHub UI to assist in code review in [Chrome](https://chrome.google.com/webstore/detail/codecov/gedikamndpbemklijjkncpnolildpbgo) or Firefox (https://addons.mozilla.org/en-US/firefox/addon/codecov/)\r\n\r\n*Highly detailed* **pull request comments** and *customizable* **commit statuses** will improve your team's workflow and code coverage incrementally.\r\n\r\n**File backed configuration** all through the `codecov.yml`. \r\n\r\n## FAQ\r\n- Do you **merge multiple uploads** to the same commit? **Yes**\r\n- Do you **support multiple languages** in the same project? **Yes**\r\n- Can you **group coverage reports** by project and/or test type? **Yes**\r\n- How does **pricing** work? Only paid users can view reports and post statuses/comments. ",
#      'external_url': 'https://codecov.io',
#      'html_url': 'https://github.com/apps/codecov',
#      'created_at': '2016-09-25T14:18:27Z',
#      'updated_at': '2023-09-08T15:29:16Z',
#      'permissions': {'administration': 'read',
#       'checks': 'write',
#       'contents': 'read',
#       'emails': 'read',
#       'issues': 'read',
#       'members': 'read',
#       'metadata': 'read',
#       'pull_requests': 'write',
#       'statuses': 'write'},
#      'events': ['check_run',
#       'check_suite',
#       'create',
#       'delete',
#       'fork',
#       'member',
#       'membership',
#       'organization',
#       'public',
#       'pull_request',
#       'push',
#       'release',
#       'repository',
#       'status',
#       'team_add']}}},
#   'public': True,
#   'created_at': '2025-02-11T20:54:54Z',
#   'org': {'id': 179618328,
#    'login': 'partcad',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/partcad',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/179618328?'}},
#  {'id': '46467489080',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 29139614,
#    'login': 'renovate[bot]',
#    'display_login': 'renovate',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/renovate[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29139614?'},
#   'repo': {'id': 824636285,
#    'name': 'mariosknl/carepulse',
#    'url': 'https://api.github.com/repos/mariosknl/carepulse'},
#   'payload': {'action': 'opened',
#    'number': 93,
#    'pull_request': {'url': 'https://api.github.com/repos/mariosknl/carepulse/pulls/93',
#     'id': 2329726411,
#     'node_id': 'PR_kwDOMSbzfc6K3M3L',
#     'html_url': 'https://github.com/mariosknl/carepulse/pull/93',
#     'diff_url': 'https://github.com/mariosknl/carepulse/pull/93.diff',
#     'patch_url': 'https://github.com/mariosknl/carepulse/pull/93.patch',
#     'issue_url': 'https://api.github.com/repos/mariosknl/carepulse/issues/93',
#     'number': 93,
#     'state': 'open',
#     'locked': False,
#     'title': 'Update dependency @sentry/nextjs to v9',
#     'user': {'login': 'renovate[bot]',
#      'id': 29139614,
#      'node_id': 'MDM6Qm90MjkxMzk2MTQ=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/2740?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/renovate%5Bbot%5D',
#      'html_url': 'https://github.com/apps/renovate',
#      'followers_url': 'https://api.github.com/users/renovate%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/renovate%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/renovate%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/renovate%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/renovate%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/renovate%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/renovate%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/renovate%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/renovate%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'body': 'This PR contains the following updates:\n\n| Package | Change | Age | Adoption | Passing | Confidence |\n|---|---|---|---|---|---|\n| [@sentry/nextjs](https://redirect.github.com/getsentry/sentry-javascript/tree/master/packages/nextjs) ([source](https://redirect.github.com/getsentry/sentry-javascript)) | [`^8` -> `^9.0.0`](https://renovatebot.com/diffs/npm/@sentry%2fnextjs/8.54.0/9.0.1) | [![age](https://developer.mend.io/api/mc/badges/age/npm/@sentry%2fnextjs/9.0.1?slim=true)](https://docs.renovatebot.com/merge-confidence/) | [![adoption](https://developer.mend.io/api/mc/badges/adoption/npm/@sentry%2fnextjs/9.0.1?slim=true)](https://docs.renovatebot.com/merge-confidence/) | [![passing](https://developer.mend.io/api/mc/badges/compatibility/npm/@sentry%2fnextjs/8.54.0/9.0.1?slim=true)](https://docs.renovatebot.com/merge-confidence/) | [![confidence](https://developer.mend.io/api/mc/badges/confidence/npm/@sentry%2fnextjs/8.54.0/9.0.1?slim=true)](https://docs.renovatebot.com/merge-confidence/) |\n\n---\n\n### Release Notes\n\n<details>\n<summary>getsentry/sentry-javascript (@&#8203;sentry/nextjs)</summary>\n\n### [`v9.0.1`](https://redirect.github.com/getsentry/sentry-javascript/releases/tag/9.0.1)\n\n[Compare Source](https://redirect.github.com/getsentry/sentry-javascript/compare/9.0.0...9.0.1)\n\n-   ref(flags): rename unleash integration param ([#&#8203;15343](https://redirect.github.com/getsentry/sentry-javascript/pull/15343))\n\n##### Bundle size 📦\n\n| Path                                                             | Size              |\n| ---------------------------------------------------------------- | ----------------- |\n| [@&#8203;sentry/browser](https://redirect.github.com/sentry/browser)                                                  | 22.9 KB   |\n| [@&#8203;sentry/browser](https://redirect.github.com/sentry/browser) - with treeshaking flags                         | 22.69 KB  |\n| [@&#8203;sentry/browser](https://redirect.github.com/sentry/browser) (incl. Tracing)                                  | 35.77 KB  |\n| [@&#8203;sentry/browser](https://redirect.github.com/sentry/browser) (incl. Tracing, Replay)                          | 72.65 KB  |\n| [@&#8203;sentry/browser](https://redirect.github.com/sentry/browser) (incl. Tracing, Replay) - with treeshaking flags | 66.13 KB  |\n| [@&#8203;sentry/browser](https://redirect.github.com/sentry/browser) (incl. Tracing, Replay with Canvas)              | 76.9 KB   |\n| [@&#8203;sentry/browser](https://redirect.github.com/sentry/browser) (incl. Tracing, Replay, Feedback)                | 89.64 KB  |\n| [@&#8203;sentry/browser](https://redirect.github.com/sentry/browser) (incl. Feedback)                                 | 39.86 KB  |\n| [@&#8203;sentry/browser](https://redirect.github.com/sentry/browser) (incl. sendFeedback)                             | 27.53 KB  |\n| [@&#8203;sentry/browser](https://redirect.github.com/sentry/browser) (incl. FeedbackAsync)                            | 32.31 KB  |\n| [@&#8203;sentry/react](https://redirect.github.com/sentry/react)                                                    | 24.74 KB  |\n| [@&#8203;sentry/react](https://redirect.github.com/sentry/react) (incl. Tracing)                                    | 37.67 KB  |\n| [@&#8203;sentry/vue](https://redirect.github.com/sentry/vue)                                                      | 27.09 KB  |\n| [@&#8203;sentry/vue](https://redirect.github.com/sentry/vue) (incl. Tracing)                                      | 37.47 KB  |\n| [@&#8203;sentry/svelte](https://redirect.github.com/sentry/svelte)                                                   | 22.94 KB  |\n| CDN Bundle                                                       | 24.13 KB  |\n| CDN Bundle (incl. Tracing)                                       | 35.84 KB  |\n| CDN Bundle (incl. Tracing, Replay)                               | 70.55 KB  |\n| CDN Bundle (incl. Tracing, Replay, Feedback)                     | 75 ...
#     'created_at': '2025-02-11T20:54:51Z',
#     'updated_at': '2025-02-11T20:54:51Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': '71c862609cdacfdd3b21155790cbd980a1399952',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/mariosknl/carepulse/pulls/93/commits',
#     'review_comments_url': 'https://api.github.com/repos/mariosknl/carepulse/pulls/93/comments',
#     'review_comment_url': 'https://api.github.com/repos/mariosknl/carepulse/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/mariosknl/carepulse/issues/93/comments',
#     'statuses_url': 'https://api.github.com/repos/mariosknl/carepulse/statuses/fb1d6b697a75747e67d1ef6d57593ac32e44f3ba',
#     'head': {'label': 'mariosknl:renovate/major-sentry-javascript-monorepo',
#      'ref': 'renovate/major-sentry-javascript-monorepo',
#      'sha': 'fb1d6b697a75747e67d1ef6d57593ac32e44f3ba',
#      'user': {'login': 'mariosknl',
#       'id': 50610396,
#       'node_id': 'MDQ6VXNlcjUwNjEwMzk2',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/50610396?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/mariosknl',
#       'html_url': 'https://github.com/mariosknl',
#       'followers_url': 'https://api.github.com/users/mariosknl/followers',
#       'following_url': 'https://api.github.com/users/mariosknl/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/mariosknl/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/mariosknl/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/mariosknl/subscriptions',
#       'organizations_url': 'https://api.github.com/users/mariosknl/orgs',
#       'repos_url': 'https://api.github.com/users/mariosknl/repos',
#       'events_url': 'https://api.github.com/users/mariosknl/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/mariosknl/received_events',
#       'type': 'User',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'repo': {'id': 824636285,
#       'node_id': 'R_kgDOMSbzfQ',
#       'name': 'carepulse',
#       'full_name': 'mariosknl/carepulse',
#       'private': False,
#       'owner': {'login': 'mariosknl',
#        'id': 50610396,
#        'node_id': 'MDQ6VXNlcjUwNjEwMzk2',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/50610396?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/mariosknl',
#        'html_url': 'https://github.com/mariosknl',
#        'followers_url': 'https://api.github.com/users/mariosknl/followers',
#        'following_url': 'https://api.github.com/users/mariosknl/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/mariosknl/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/mariosknl/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/mariosknl/subscriptions',
#        'organizations_url': 'https://api.github.com/users/mariosknl/orgs',
#        'repos_url': 'https://api.github.com/users/mariosknl/repos',
#        'events_url': 'https://api.github.com/users/mariosknl/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/mariosknl/received_events',
#        'type': 'User',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'html_url': 'https://github.com/mariosknl/carepulse',
#       'description': 'A healthcare management system using Next.js | Twilio | Typescript | AppWrite | TailwindCSS etc.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/mariosknl/carepulse',
#       'forks_url': 'https://api.github.com/repos/mariosknl/carepulse/forks',
#       'keys_url': 'https://api.github.com/repos/mariosknl/carepulse/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/mariosknl/carepulse/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/mariosknl/carepulse/teams',
#       'hooks_url': 'https://api.github.com/repos/mariosknl/carepulse/hooks',
#       'issue_events_url': 'https://api.github.com/repos/mariosknl/carepulse/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/mariosknl/carepulse/events',
#       'assignees_url': 'https://api.github.com/repos/mariosknl/carepulse/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/mariosknl/carepulse/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/mariosknl/carepulse/tags',
#       'blobs_url': 'https://api.github.com/repos/mariosknl/carepulse/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/mariosknl/carepulse/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/mariosknl/carepulse/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/mariosknl/carepulse/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/mariosknl/carepulse/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/mariosknl/carepulse/languages',
#       'stargazers_url': 'https://api.github.com/repos/mariosknl/carepulse/stargazers',
#       'contributors_url': 'https://api.github.com/repos/mariosknl/carepulse/contributors',
#       'subscribers_url': 'https://api.github.com/repos/mariosknl/carepulse/subscribers',
#       'subscription_url': 'https://api.github.com/repos/mariosknl/carepulse/subscription',
#       'commits_url': 'https://api.github.com/repos/mariosknl/carepulse/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/mariosknl/carepulse/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/mariosknl/carepulse/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/mariosknl/carepulse/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/mariosknl/carepulse/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/mariosknl/carepulse/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/mariosknl/carepulse/merges',
#       'archive_url': 'https://api.github.com/repos/mariosknl/carepulse/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/mariosknl/carepulse/downloads',
#       'issues_url': 'https://api.github.com/repos/mariosknl/carepulse/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/mariosknl/carepulse/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/mariosknl/carepulse/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/mariosknl/carepulse/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/mariosknl/carepulse/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/mariosknl/carepulse/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/mariosknl/carepulse/deployments',
#       'created_at': '2024-07-05T15:06:31Z',
#       'updated_at': '2025-02-10T07:29:00Z',
#       'pushed_at': '2025-02-11T20:54:53Z',
#       'git_url': 'git://github.com/mariosknl/carepulse.git',
#       'ssh_url': 'git@github.com:mariosknl/carepulse.git',
#       'clone_url': 'https://github.com/mariosknl/carepulse.git',
#       'svn_url': 'https://github.com/mariosknl/carepulse',
#       'homepage': None,
#       'size': 4756,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 7,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 7,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     'base': {'label': 'mariosknl:main',
#      'ref': 'main',
#      'sha': '1fedc974881bef5621b0d354e077751785f4c390',
#      'user': {'login': 'mariosknl',
#       'id': 50610396,
#       'node_id': 'MDQ6VXNlcjUwNjEwMzk2',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/50610396?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/mariosknl',
#       'html_url': 'https://github.com/mariosknl',
#       'followers_url': 'https://api.github.com/users/mariosknl/followers',
#       'following_url': 'https://api.github.com/users/mariosknl/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/mariosknl/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/mariosknl/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/mariosknl/subscriptions',
#       'organizations_url': 'https://api.github.com/users/mariosknl/orgs',
#       'repos_url': 'https://api.github.com/users/mariosknl/repos',
#       'events_url': 'https://api.github.com/users/mariosknl/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/mariosknl/received_events',
#       'type': 'User',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'repo': {'id': 824636285,
#       'node_id': 'R_kgDOMSbzfQ',
#       'name': 'carepulse',
#       'full_name': 'mariosknl/carepulse',
#       'private': False,
#       'owner': {'login': 'mariosknl',
#        'id': 50610396,
#        'node_id': 'MDQ6VXNlcjUwNjEwMzk2',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/50610396?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/mariosknl',
#        'html_url': 'https://github.com/mariosknl',
#        'followers_url': 'https://api.github.com/users/mariosknl/followers',
#        'following_url': 'https://api.github.com/users/mariosknl/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/mariosknl/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/mariosknl/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/mariosknl/subscriptions',
#        'organizations_url': 'https://api.github.com/users/mariosknl/orgs',
#        'repos_url': 'https://api.github.com/users/mariosknl/repos',
#        'events_url': 'https://api.github.com/users/mariosknl/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/mariosknl/received_events',
#        'type': 'User',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'html_url': 'https://github.com/mariosknl/carepulse',
#       'description': 'A healthcare management system using Next.js | Twilio | Typescript | AppWrite | TailwindCSS etc.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/mariosknl/carepulse',
#       'forks_url': 'https://api.github.com/repos/mariosknl/carepulse/forks',
#       'keys_url': 'https://api.github.com/repos/mariosknl/carepulse/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/mariosknl/carepulse/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/mariosknl/carepulse/teams',
#       'hooks_url': 'https://api.github.com/repos/mariosknl/carepulse/hooks',
#       'issue_events_url': 'https://api.github.com/repos/mariosknl/carepulse/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/mariosknl/carepulse/events',
#       'assignees_url': 'https://api.github.com/repos/mariosknl/carepulse/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/mariosknl/carepulse/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/mariosknl/carepulse/tags',
#       'blobs_url': 'https://api.github.com/repos/mariosknl/carepulse/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/mariosknl/carepulse/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/mariosknl/carepulse/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/mariosknl/carepulse/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/mariosknl/carepulse/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/mariosknl/carepulse/languages',
#       'stargazers_url': 'https://api.github.com/repos/mariosknl/carepulse/stargazers',
#       'contributors_url': 'https://api.github.com/repos/mariosknl/carepulse/contributors',
#       'subscribers_url': 'https://api.github.com/repos/mariosknl/carepulse/subscribers',
#       'subscription_url': 'https://api.github.com/repos/mariosknl/carepulse/subscription',
#       'commits_url': 'https://api.github.com/repos/mariosknl/carepulse/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/mariosknl/carepulse/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/mariosknl/carepulse/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/mariosknl/carepulse/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/mariosknl/carepulse/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/mariosknl/carepulse/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/mariosknl/carepulse/merges',
#       'archive_url': 'https://api.github.com/repos/mariosknl/carepulse/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/mariosknl/carepulse/downloads',
#       'issues_url': 'https://api.github.com/repos/mariosknl/carepulse/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/mariosknl/carepulse/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/mariosknl/carepulse/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/mariosknl/carepulse/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/mariosknl/carepulse/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/mariosknl/carepulse/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/mariosknl/carepulse/deployments',
#       'created_at': '2024-07-05T15:06:31Z',
#       'updated_at': '2025-02-10T07:29:00Z',
#       'pushed_at': '2025-02-11T20:54:53Z',
#       'git_url': 'git://github.com/mariosknl/carepulse.git',
#       'ssh_url': 'git@github.com:mariosknl/carepulse.git',
#       'clone_url': 'https://github.com/mariosknl/carepulse.git',
#       'svn_url': 'https://github.com/mariosknl/carepulse',
#       'homepage': None,
#       'size': 4756,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 7,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 7,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/mariosknl/carepulse/pulls/93'},
#      'html': {'href': 'https://github.com/mariosknl/carepulse/pull/93'},
#      'issue': {'href': 'https://api.github.com/repos/mariosknl/carepulse/issues/93'},
#      'comments': {'href': 'https://api.github.com/repos/mariosknl/carepulse/issues/93/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/mariosknl/carepulse/pulls/93/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/mariosknl/carepulse/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/mariosknl/carepulse/pulls/93/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/mariosknl/carepulse/statuses/fb1d6b697a75747e67d1ef6d57593ac32e44f3ba'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': True,
#     'rebaseable': True,
#     'mergeable_state': 'clean',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 120,
#     'deletions': 134,
#     'changed_files': 2}},
#   'public': True,
#   'created_at': '2025-02-11T20:54:54Z'},
#  {'id': '46467489065',
#   'type': 'PushEvent',
#   'actor': {'id': 106306616,
#    'login': 'pavlo-kh',
#    'display_login': 'pavlo-kh',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pavlo-kh',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/106306616?'},
#   'repo': {'id': 530816618,
#    'name': 'SuperUnlimited/data-backup',
#    'url': 'https://api.github.com/repos/SuperUnlimited/data-backup'},
#   'payload': {'repository_id': 530816618,
#    'push_id': 22602683956,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/v3',
#    'head': '06432775e60a3174a3a1dcb44d4e9b7d0ba52491',
#    'before': '6a507319960ae3d91cf97adde23bb8e78e1cd952',
#    'commits': [{'sha': '06432775e60a3174a3a1dcb44d4e9b7d0ba52491',
#      'author': {'email': 'data-bot@superunlimited.com', 'name': 'DataBot'},
#      'message': '2025-02-11 20:53:28 FC:3591 UFC:82 UFS:1.27M T:83.30s',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/SuperUnlimited/data-backup/commits/06432775e60a3174a3a1dcb44d4e9b7d0ba52491'}]},
#   'public': True,
#   'created_at': '2025-02-11T20:54:54Z',
#   'org': {'id': 76759182,
#    'login': 'SuperUnlimited',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/SuperUnlimited',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/76759182?'}},
#  {'id': '46467489049',
#   'type': 'PushEvent',
#   'actor': {'id': 10497648,
#    'login': 'chaasfr',
#    'display_login': 'chaasfr',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/chaasfr',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10497648?'},
#   'repo': {'id': 930544988,
#    'name': 'chaasfr/cicd-exercise',
#    'url': 'https://api.github.com/repos/chaasfr/cicd-exercise'},
#   'payload': {'repository_id': 930544988,
#    'push_id': 22602684068,
#    'size': 7,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'ffef7e68b3e38560d5c26197fe7959750cb477ab',
#    'before': '59115e60e9e3bec611390f67ad40c6b2bd696db5',
#    'commits': [{'sha': '3f1299b58df780b0885d623659d64a93d2e1d1e2',
#      'author': {'email': 'chaasfr@gmail.com', 'name': 'chaasfr'},
#      'message': 'added readme update',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/chaasfr/cicd-exercise/commits/3f1299b58df780b0885d623659d64a93d2e1d1e2'},
#     {'sha': 'e9dcc0c699f8b444e8e171b422bd923de6a65b76',
#      'author': {'email': 'chaasfr@gmail.com', 'name': 'chaasfr'},
#      'message': 'added github basic CI',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/chaasfr/cicd-exercise/commits/e9dcc0c699f8b444e8e171b422bd923de6a65b76'},
#     {'sha': '28de1dea7b968fb3c58aa930e2b692e7be9a80df',
#      'author': {'email': 'chaasfr@gmail.com', 'name': 'chaasfr'},
#      'message': 'updated ci',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/chaasfr/cicd-exercise/commits/28de1dea7b968fb3c58aa930e2b692e7be9a80df'},
#     {'sha': 'cf4207d500af7fa17f8cda26092a606e21d9eb07',
#      'author': {'email': 'chaasfr@gmail.com', 'name': 'chaasfr'},
#      'message': 'added unit test on api key and ci step for unit tests',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/chaasfr/cicd-exercise/commits/cf4207d500af7fa17f8cda26092a606e21d9eb07'},
#     {'sha': 'c2fe977f85bf8d91fc4157a75753580cb7f7eaf5',
#      'author': {'email': 'chaasfr@gmail.com', 'name': 'chaasfr'},
#      'message': 'added test coverage for unit tests',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/chaasfr/cicd-exercise/commits/c2fe977f85bf8d91fc4157a75753580cb7f7eaf5'},
#     {'sha': 'b4bcbe45e61e4fbf23f59be3e54bd98a82daa649',
#      'author': {'email': 'chaasfr@gmail.com', 'name': 'chaasfr'},
#      'message': 'added test coverage badge',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/chaasfr/cicd-exercise/commits/b4bcbe45e61e4fbf23f59be3e54bd98a82daa649'},
#     {'sha': 'ffef7e68b3e38560d5c26197fe7959750cb477ab',
#      'author': {'email': 'chaasfr@gmail.com', 'name': 'Christian Haas-Frangi'},
#      'message': 'Merge pull request #1 from chaasfr/addtests\n\nadded ci and unittests',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/chaasfr/cicd-exercise/commits/ffef7e68b3e38560d5c26197fe7959750cb477ab'}]},
#   'public': True,
#   'created_at': '2025-02-11T20:54:54Z'},
#  {'id': '46467486970',
#   'type': 'PushEvent',
#   'actor': {'id': 192887978,
#    'login': 'Tomsharma756',
#    'display_login': 'Tomsharma756',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Tomsharma756',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/192887978?'},
#   'repo': {'id': 908607544,
#    'name': 'Tomsharma756/StatCraft',
#    'url': 'https://api.github.com/repos/Tomsharma756/StatCraft'},
#   'payload': {'repository_id': 908607544,
#    'push_id': 22602683037,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '906c45d970b15bdfa4fbc548a6f3571dbc030cc5',
#    'before': 'aaac8d3c371db192c8bd940fc293f952b4eef3c7',
#    'commits': [{'sha': '906c45d970b15bdfa4fbc548a6f3571dbc030cc5',
#      'author': {'email': 'tomsharma756@gmail.com', 'name': 'Tomsharma756'},
#      'message': 'United-States-Lavandula-Angustifolia-Oil-Market.md\n\nUnited States Lavandula Angustifolia Oil Market By Application',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Tomsharma756/StatCraft/commits/906c45d970b15bdfa4fbc548a6f3571dbc030cc5'}]},
#   'public': True,
#   'created_at': '2025-02-11T20:54:50Z'},
#  {'id': '46467489048',
#   'type': 'CreateEvent',
#   'actor': {'id': 34928439,
#    'login': 'jrmccluskey',
#    'display_login': 'jrmccluskey',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jrmccluskey',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/34928439?'},
#   'repo': {'id': 50904245,
#    'name': 'apache/beam',
#    'url': 'https://api.github.com/repos/apache/beam'},
#   'payload': {'ref': 'v2.63.0-RC2',
#    'ref_type': 'tag',
#    'master_branch': 'master',
#    'description': 'Apache Beam is a unified programming model for Batch and Streaming data processing.',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2025-02-11T20:54:54Z',
#   'org': {'id': 47359,
#    'login': 'apache',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/apache',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47359?'}},
#  {'id': '46467489002',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 930798687,
#    'name': 'tranyiawqilong/refactored-octo-telegram',
#    'url': 'https://api.github.com/repos/tranyiawqilong/refactored-octo-telegram'},
#   'payload': {'repository_id': 930798687,
#    'push_id': 22602684019,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '50ad53ea3288db7d3a1ec6edf6a4c62cb08a6d23',
#    'before': '11968e78e3950eb756096d06555a66972c6bf427',
#    'commits': [{'sha': '50ad53ea3288db7d3a1ec6edf6a4c62cb08a6d23',
#      'author': {'email': 'qilong711@mail.com', 'name': 'tranyiawqilong'},
#      'message': '2025-01-02T20:54:51+00:00',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/tranyiawqilong/refactored-octo-telegram/commits/50ad53ea3288db7d3a1ec6edf6a4c62cb08a6d23'}]},
#   'public': True,
#   'created_at': '2025-02-11T20:54:54Z'},
#  {'id': '46467489036',
#   'type': 'PushEvent',
#   'actor': {'id': 187670907,
#    'login': 'Jerwinator',
#    'display_login': 'Jerwinator',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Jerwinator',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/187670907?'},
#   'repo': {'id': 884978878,
#    'name': 'Jerwinator/artisansus',
#    'url': 'https://api.github.com/repos/Jerwinator/artisansus'},
#   'payload': {'repository_id': 884978878,
#    'push_id': 22602684080,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '5fd4fdadb5ae90245400b6aa6c5c12613e8883a1',
#    'before': '0e0cbf48a4af95a5e83b272316e95de3a01a8eda',
#    'commits': [{'sha': '5fd4fdadb5ae90245400b6aa6c5c12613e8883a1',
#      'author': {'email': 'jerwin@basicfundamentals.com', 'name': 'Jerwinator'},
#      'message': 'Delete M2 - BFS-CBC-WED-C002_L1.jpg',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Jerwinator/artisansus/commits/5fd4fdadb5ae90245400b6aa6c5c12613e8883a1'}]},
#   'public': True,
#   'created_at': '2025-02-11T20:54:54Z'},
#  {'id': '46467489046',
#   'type': 'WatchEvent',
#   'actor': {'id': 3309992,
#    'login': 'MTouny',
#    'display_login': 'MTouny',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MTouny',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3309992?'},
#   'repo': {'id': 13491895,
#    'name': 'EbookFoundation/free-programming-books',
# ...
#       'repos_url': 'https://api.github.com/users/nfmahadi/repos',
#       'events_url': 'https://api.github.com/users/nfmahadi/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/nfmahadi/received_events',
#       'type': 'User',
#       'user_view_type': 'public',
#       'site_admin': False}],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/mahadihk/nefertiti/pulls/2/commits',
#     'review_comments_url': 'https://api.github.com/repos/mahadihk/nefertiti/pulls/2/comments',
#     'review_comment_url': 'https://api.github.com/repos/mahadihk/nefertiti/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/mahadihk/nefertiti/issues/2/comments',
#     'statuses_url': 'https://api.github.com/repos/mahadihk/nefertiti/statuses/b9a46cd226dfaa21991bc5d62bec69e47ad6c8a0',
#     'head': {'label': 'mahadihk:malf23',
#      'ref': 'malf23',
#      'sha': 'b9a46cd226dfaa21991bc5d62bec69e47ad6c8a0',
#      'user': {'login': 'mahadihk',
#       'id': 40921303,
#       'node_id': 'MDQ6VXNlcjQwOTIxMzAz',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/40921303?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/mahadihk',
#       'html_url': 'https://github.com/mahadihk',
#       'followers_url': 'https://api.github.com/users/mahadihk/followers',
#       'following_url': 'https://api.github.com/users/mahadihk/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/mahadihk/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/mahadihk/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/mahadihk/subscriptions',
#       'organizations_url': 'https://api.github.com/users/mahadihk/orgs',
#       'repos_url': 'https://api.github.com/users/mahadihk/repos',
#       'events_url': 'https://api.github.com/users/mahadihk/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/mahadihk/received_events',
#       'type': 'User',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'repo': {'id': 702611922,
#       'node_id': 'R_kgDOKeEB0g',
#       'name': 'nefertiti',
#       'full_name': 'mahadihk/nefertiti',
#       'private': False,
#       'owner': {'login': 'mahadihk',
#        'id': 40921303,
#        'node_id': 'MDQ6VXNlcjQwOTIxMzAz',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/40921303?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/mahadihk',
#        'html_url': 'https://github.com/mahadihk',
#        'followers_url': 'https://api.github.com/users/mahadihk/followers',
#        'following_url': 'https://api.github.com/users/mahadihk/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/mahadihk/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/mahadihk/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/mahadihk/subscriptions',
#        'organizations_url': 'https://api.github.com/users/mahadihk/orgs',
#        'repos_url': 'https://api.github.com/users/mahadihk/repos',
#        'events_url': 'https://api.github.com/users/mahadihk/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/mahadihk/received_events',
#        'type': 'User',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'html_url': 'https://github.com/mahadihk/nefertiti',
#       'description': 'Personal Portfolio Website',
#       'fork': False,
#       'url': 'https://api.github.com/repos/mahadihk/nefertiti',
#       'forks_url': 'https://api.github.com/repos/mahadihk/nefertiti/forks',
#       'keys_url': 'https://api.github.com/repos/mahadihk/nefertiti/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/mahadihk/nefertiti/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/mahadihk/nefertiti/teams',
#       'hooks_url': 'https://api.github.com/repos/mahadihk/nefertiti/hooks',
#       'issue_events_url': 'https://api.github.com/repos/mahadihk/nefertiti/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/mahadihk/nefertiti/events',
#       'assignees_url': 'https://api.github.com/repos/mahadihk/nefertiti/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/mahadihk/nefertiti/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/mahadihk/nefertiti/tags',
#       'blobs_url': 'https://api.github.com/repos/mahadihk/nefertiti/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/mahadihk/nefertiti/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/mahadihk/nefertiti/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/mahadihk/nefertiti/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/mahadihk/nefertiti/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/mahadihk/nefertiti/languages',
#       'stargazers_url': 'https://api.github.com/repos/mahadihk/nefertiti/stargazers',
#       'contributors_url': 'https://api.github.com/repos/mahadihk/nefertiti/contributors',
#       'subscribers_url': 'https://api.github.com/repos/mahadihk/nefertiti/subscribers',
#       'subscription_url': 'https://api.github.com/repos/mahadihk/nefertiti/subscription',
#       'commits_url': 'https://api.github.com/repos/mahadihk/nefertiti/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/mahadihk/nefertiti/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/mahadihk/nefertiti/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/mahadihk/nefertiti/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/mahadihk/nefertiti/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/mahadihk/nefertiti/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/mahadihk/nefertiti/merges',
#       'archive_url': 'https://api.github.com/repos/mahadihk/nefertiti/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/mahadihk/nefertiti/downloads',
#       'issues_url': 'https://api.github.com/repos/mahadihk/nefertiti/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/mahadihk/nefertiti/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/mahadihk/nefertiti/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/mahadihk/nefertiti/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/mahadihk/nefertiti/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/mahadihk/nefertiti/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/mahadihk/nefertiti/deployments',
#       'created_at': '2023-10-09T16:36:57Z',
#       'updated_at': '2025-02-11T20:51:01Z',
#       'pushed_at': '2025-02-11T20:52:51Z',
#       'git_url': 'git://github.com/mahadihk/nefertiti.git',
#       'ssh_url': 'git@github.com:mahadihk/nefertiti.git',
#       'clone_url': 'https://github.com/mahadihk/nefertiti.git',
#       'svn_url': 'https://github.com/mahadihk/nefertiti',
#       'homepage': None,
#       'size': 1,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'CSS',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     'base': {'label': 'mahadihk:main',
#      'ref': 'main',
#      'sha': 'afa3600f5305197e75e0fa6fc6a3d8f97411ce45',
#      'user': {'login': 'mahadihk',
#       'id': 40921303,
#       'node_id': 'MDQ6VXNlcjQwOTIxMzAz',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/40921303?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/mahadihk',
#       'html_url': 'https://github.com/mahadihk',
#       'followers_url': 'https://api.github.com/users/mahadihk/followers',
#       'following_url': 'https://api.github.com/users/mahadihk/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/mahadihk/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/mahadihk/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/mahadihk/subscriptions',
#       'organizations_url': 'https://api.github.com/users/mahadihk/orgs',
#       'repos_url': 'https://api.github.com/users/mahadihk/repos',
#       'events_url': 'https://api.github.com/users/mahadihk/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/mahadihk/received_events',
#       'type': 'User',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'repo': {'id': 702611922,
#       'node_id': 'R_kgDOKeEB0g',
#       'name': 'nefertiti',
#       'full_name': 'mahadihk/nefertiti',
#       'private': False,
#       'owner': {'login': 'mahadihk',
#        'id': 40921303,
#        'node_id': 'MDQ6VXNlcjQwOTIxMzAz',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/40921303?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/mahadihk',
#        'html_url': 'https://github.com/mahadihk',
#        'followers_url': 'https://api.github.com/users/mahadihk/followers',
#        'following_url': 'https://api.github.com/users/mahadihk/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/mahadihk/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/mahadihk/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/mahadihk/subscriptions',
#        'organizations_url': 'https://api.github.com/users/mahadihk/orgs',
#        'repos_url': 'https://api.github.com/users/mahadihk/repos',
#        'events_url': 'https://api.github.com/users/mahadihk/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/mahadihk/received_events',
#        'type': 'User',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'html_url': 'https://github.com/mahadihk/nefertiti',
#       'description': 'Personal Portfolio Website',
#       'fork': False,
#       'url': 'https://api.github.com/repos/mahadihk/nefertiti',
#       'forks_url': 'https://api.github.com/repos/mahadihk/nefertiti/forks',
#       'keys_url': 'https://api.github.com/repos/mahadihk/nefertiti/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/mahadihk/nefertiti/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/mahadihk/nefertiti/teams',
#       'hooks_url': 'https://api.github.com/repos/mahadihk/nefertiti/hooks',
#       'issue_events_url': 'https://api.github.com/repos/mahadihk/nefertiti/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/mahadihk/nefertiti/events',
#       'assignees_url': 'https://api.github.com/repos/mahadihk/nefertiti/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/mahadihk/nefertiti/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/mahadihk/nefertiti/tags',
#       'blobs_url': 'https://api.github.com/repos/mahadihk/nefertiti/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/mahadihk/nefertiti/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/mahadihk/nefertiti/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/mahadihk/nefertiti/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/mahadihk/nefertiti/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/mahadihk/nefertiti/languages',
#       'stargazers_url': 'https://api.github.com/repos/mahadihk/nefertiti/stargazers',
#       'contributors_url': 'https://api.github.com/repos/mahadihk/nefertiti/contributors',
#       'subscribers_url': 'https://api.github.com/repos/mahadihk/nefertiti/subscribers',
#       'subscription_url': 'https://api.github.com/repos/mahadihk/nefertiti/subscription',
#       'commits_url': 'https://api.github.com/repos/mahadihk/nefertiti/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/mahadihk/nefertiti/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/mahadihk/nefertiti/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/mahadihk/nefertiti/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/mahadihk/nefertiti/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/mahadihk/nefertiti/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/mahadihk/nefertiti/merges',
#       'archive_url': 'https://api.github.com/repos/mahadihk/nefertiti/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/mahadihk/nefertiti/downloads',
#       'issues_url': 'https://api.github.com/repos/mahadihk/nefertiti/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/mahadihk/nefertiti/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/mahadihk/nefertiti/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/mahadihk/nefertiti/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/mahadihk/nefertiti/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/mahadihk/nefertiti/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/mahadihk/nefertiti/deployments',
#       'created_at': '2023-10-09T16:36:57Z',
#       'updated_at': '2025-02-11T20:51:01Z',
#       'pushed_at': '2025-02-11T20:52:51Z',
#       'git_url': 'git://github.com/mahadihk/nefertiti.git',
#       'ssh_url': 'git@github.com:mahadihk/nefertiti.git',
#       'clone_url': 'https://github.com/mahadihk/nefertiti.git',
#       'svn_url': 'https://github.com/mahadihk/nefertiti',
#       'homepage': None,
#       'size': 1,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'CSS',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/mahadihk/nefertiti/pulls/2'},
#      'html': {'href': 'https://github.com/mahadihk/nefertiti/pull/2'},
#      'issue': {'href': 'https://api.github.com/repos/mahadihk/nefertiti/issues/2'},
#      'comments': {'href': 'https://api.github.com/repos/mahadihk/nefertiti/issues/2/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/mahadihk/nefertiti/pulls/2/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/mahadihk/nefertiti/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/mahadihk/nefertiti/pulls/2/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/mahadihk/nefertiti/statuses/b9a46cd226dfaa21991bc5d62bec69e47ad6c8a0'}},
#     'author_association': 'OWNER',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 2,
#     'additions': 3,
#     'deletions': 2,
#     'changed_files': 2}},
#   'public': True,
#   'created_at': '2025-02-11T20:54:54Z'}]

# %% [markdown]
# Utilizando outro endpoint

# %%
r = requests.get('https://api.github.com/versions')
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# ['2022-11-28']

# %% [markdown]
# ## Extraindo dados

# %% [markdown]
# ### Obtendo dados dos repositórios

# %%
# especificando a versão da API

headers = {'X-GitHub-Api-Version': '2022-11-28'}

# %%
api_base_url = 'https://api.github.com'
owner = 'amzn' #username de onde vai ser coletado os dados
url = f'{api_base_url}/users/{owner}/repos'

# %%
url
# Out:
# 'https://api.github.com/users/amzn/repos'

# %%
response = requests.get(url, headers=headers)
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# [{'id': 171339259,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxNzEzMzkyNTk=',
#   'name': '.github',
#   'full_name': 'amzn/.github',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/.github',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/.github',
#   'forks_url': 'https://api.github.com/repos/amzn/.github/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/.github/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/.github/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/.github/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/.github/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/.github/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/.github/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/.github/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/.github/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/.github/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/.github/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/.github/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/.github/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/.github/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/.github/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/.github/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/.github/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/.github/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/.github/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/.github/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/.github/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/.github/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/.github/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/.github/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/.github/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/.github/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/.github/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/.github/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/.github/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/.github/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/.github/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/.github/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/.github/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/.github/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/.github/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/.github/deployments',
#   'created_at': '2019-02-18T18:59:22Z',
#   'updated_at': '2025-01-23T06:17:33Z',
#   'pushed_at': '2024-10-18T22:23:05Z',
#   'git_url': 'git://github.com/amzn/.github.git',
#   'ssh_url': 'git@github.com:amzn/.github.git',
#   'clone_url': 'https://github.com/amzn/.github.git',
#   'svn_url': 'https://github.com/amzn/.github',
#   'homepage': None,
#   'size': 24,
#   'stargazers_count': 15,
#   'watchers_count': 15,
#   'language': None,
#   'has_issues': True,
#   'has_projects': False,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 367,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 3,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 367,
#   'open_issues': 3,
#   'watchers': 15,
#   'default_branch': 'master'},
#  {'id': 492978607,
#   'node_id': 'R_kgDOHWJBrw',
#   'name': 'ads-advanced-tools-docs',
#   'full_name': 'amzn/ads-advanced-tools-docs',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/ads-advanced-tools-docs',
#   'description': 'Code samples and supplements for the Amazon Ads advanced tools center',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs',
#   'forks_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/deployments',
#   'created_at': '2022-05-16T19:49:03Z',
#   'updated_at': '2025-02-08T03:06:07Z',
#   'pushed_at': '2025-01-29T14:49:12Z',
#   'git_url': 'git://github.com/amzn/ads-advanced-tools-docs.git',
#   'ssh_url': 'git@github.com:amzn/ads-advanced-tools-docs.git',
#   'clone_url': 'https://github.com/amzn/ads-advanced-tools-docs.git',
#   'svn_url': 'https://github.com/amzn/ads-advanced-tools-docs',
#   'homepage': 'https://advertising.amazon.com/API/docs/en-us/index',
#   'size': 387,
#   'stargazers_count': 105,
#   'watchers_count': 105,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': False,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': True,
#   'forks_count': 35,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 39,
#   'license': {'key': 'mit-0',
#    'name': 'MIT No Attribution',
#    'spdx_id': 'MIT-0',
#    'url': 'https://api.github.com/licenses/mit-0',
#    'node_id': 'MDc6TGljZW5zZTQx'},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': ['amazon', 'amazon-ads-api', 'amazon-marketing-stream'],
#   'visibility': 'public',
#   'forks': 35,
#   'open_issues': 39,
#   'watchers': 105,
#   'default_branch': 'main'},
#  {'id': 674005216,
#   'node_id': 'R_kgDOKCyA4A',
#   'name': 'ads-pao-amznjs-gtm-template',
#   'full_name': 'amzn/ads-pao-amznjs-gtm-template',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template',
#   'forks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/deployments',
#   'created_at': '2023-08-02T23:41:56Z',
#   'updated_at': '2024-09-05T08:32:25Z',
#   'pushed_at': '2024-06-03T16:53:23Z',
#   'git_url': 'git://github.com/amzn/ads-pao-amznjs-gtm-template.git',
#   'ssh_url': 'git@github.com:amzn/ads-pao-amznjs-gtm-template.git',
#   'clone_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template.git',
#   'svn_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template',
#   'homepage': None,
#   'size': 165,
#   'stargazers_count': 3,
#   'watchers_count': 3,
#   'language': 'Smarty',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 3,
#   'default_branch': 'main'},
#  {'id': 41117941,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk0MTExNzk0MQ==',
#   'name': 'alexa-coho',
#   'full_name': 'amzn/alexa-coho',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/alexa-coho',
#   'description': 'Sample code for building skill adapters for Alexa Connected Home using the Lighting API',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/alexa-coho',
#   'forks_url': 'https://api.github.com/repos/amzn/alexa-coho/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/alexa-coho/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/alexa-coho/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/alexa-coho/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/alexa-coho/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/alexa-coho/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/alexa-coho/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/alexa-coho/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/alexa-coho/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/alexa-coho/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/alexa-coho/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/alexa-coho/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/alexa-coho/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/alexa-coho/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/alexa-coho/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/alexa-coho/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/alexa-coho/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/alexa-coho/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/alexa-coho/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/alexa-coho/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/alexa-coho/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/alexa-coho/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/alexa-coho/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/alexa-coho/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/alexa-coho/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/alexa-coho/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/alexa-coho/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/alexa-coho/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/alexa-coho/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/alexa-coho/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/alexa-coho/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/alexa-coho/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/alexa-coho/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/alexa-coho/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/alexa-coho/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/alexa-coho/deployments',
#   'created_at': '2015-08-20T20:42:31Z',
#   'updated_at': '2024-07-11T01:03:40Z',
#   'pushed_at': '2023-04-01T08:35:29Z',
#   'git_url': 'git://github.com/amzn/alexa-coho.git',
#   'ssh_url': 'git@github.com:amzn/alexa-coho.git',
#   'clone_url': 'https://github.com/amzn/alexa-coho.git',
#   'svn_url': 'https://github.com/amzn/alexa-coho',
#   'homepage': None,
#   'size': 209,
#   'stargazers_count': 63,
#   'watchers_count': 63,
#   'language': 'JavaScript',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 25,
#   'mirror_url': None,
#   'archived': True,
#   'disabled': False,
#   'open_issues_count': 4,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 25,
#   'open_issues': 4,
#   'watchers': 63,
#   'default_branch': 'master'},
#  {'id': 39471546,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzOTQ3MTU0Ng==',
#   'name': 'alexa-skills-kit-js',
#   'full_name': 'amzn/alexa-skills-kit-js',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/alexa-skills-kit-js',
#   'description': ' SDK and example code for building voice-enabled skills for the Amazon Echo. ',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js',
#   'forks_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/deployments',
#   'created_at': '2015-07-21T21:46:48Z',
#   'updated_at': '2024-08-04T00:31:19Z',
#   'pushed_at': '2020-10-01T06:10:20Z',
#   'git_url': 'git://github.com/amzn/alexa-skills-kit-js.git',
#   'ssh_url': 'git@github.com:amzn/alexa-skills-kit-js.git',
#   'clone_url': 'https://github.com/amzn/alexa-skills-kit-js.git',
#   'svn_url': 'https://github.com/amzn/alexa-skills-kit-js',
#   'homepage': 'http://developer.amazon.com/ask',
#   'size': 8827,
#   'stargazers_count': 1135,
#   'watchers_count': 1135,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 1037,
#   'mirror_url': None,
#   'archived': True,
#   'disabled': False,
#   'open_issues_count': 11,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 1037,
#   'open_issues': 11,
#   'watchers': 1135,
#   'default_branch': 'master'},
#  {'id': 495519526,
#   'node_id': 'R_kgDOHYkHJg',
#   'name': 'amazon-ads-advertiser-audience-normalization-sdk-py',
#   'full_name': 'amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/deployments',
#   'created_at': '2022-05-23T17:59:56Z',
#   'updated_at': '2025-01-15T02:22:55Z',
#   'pushed_at': '2022-05-23T21:20:34Z',
#   'git_url': 'git://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#   'ssh_url': 'git@github.com:amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#   'clone_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#   'svn_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'homepage': None,
#   'size': 16,
#   'stargazers_count': 10,
#   'watchers_count': 10,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 3,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'other',
#    'name': 'Other',
#    'spdx_id': 'NOASSERTION',
#    'url': None,
#    'node_id': 'MDc6TGljZW5zZTA='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 3,
#   'open_issues': 0,
#   'watchers': 10,
#   'default_branch': 'main'},
#  {'id': 61315875,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk2MTMxNTg3NQ==',
#   'name': 'amazon-advertising-api-php-sdk',
#   'full_name': 'amzn/amazon-advertising-api-php-sdk',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk',
#   'description': '⛔️ DEPRECATED - Amazon Advertising API PHP Client Library',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/deployments',
#   'created_at': '2016-06-16T18:16:46Z',
#   'updated_at': '2024-09-14T07:43:36Z',
#   'pushed_at': '2020-09-20T17:25:48Z',
#   'git_url': 'git://github.com/amzn/amazon-advertising-api-php-sdk.git',
#   'ssh_url': 'git@github.com:amzn/amazon-advertising-api-php-sdk.git',
#   'clone_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk.git',
#   'svn_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk',
#   'homepage': '',
#   'size': 49,
#   'stargazers_count': 93,
#   'watchers_count': 93,
#   'language': 'PHP',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 66,
#   'mirror_url': None,
#   'archived': True,
#   'disabled': False,
#   'open_issues_count': 14,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 66,
#   'open_issues': 14,
#   'watchers': 93,
#   'default_branch': 'master'},
#  {'id': 429297502,
#   'node_id': 'R_kgDOGZaPXg',
#   'name': 'amazon-codeguru-profiler-for-spark',
#   'full_name': 'amzn/amazon-codeguru-profiler-for-spark',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-codeguru-profiler-for-spark',
#   'description': 'A Spark plugin for CPU and memory profiling',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/deployments',
#   'created_at': '2021-11-18T04:37:55Z',
#   'updated_at': '2024-10-01T18:04:47Z',
#   'pushed_at': '2024-05-30T18:52:25Z',
#   'git_url': 'git://github.com/amzn/amazon-codeguru-profiler-for-spark.git',
#   'ssh_url': 'git@github.com:amzn/amazon-codeguru-profiler-for-spark.git',
#   'clone_url': 'https://github.com/amzn/amazon-codeguru-profiler-for-spark.git',
#   'svn_url': 'https://github.com/amzn/amazon-codeguru-profiler-for-spark',
#   'homepage': '',
#   'size': 2352,
#   'stargazers_count': 18,
#   'watchers_count': 18,
#   'language': 'Java',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 12,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 2,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
# ...
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/deployments',
#   'created_at': '2014-12-06T01:01:38Z',
#   'updated_at': '2024-07-13T00:52:34Z',
#   'pushed_at': '2024-05-30T18:46:45Z',
#   'git_url': 'git://github.com/amzn/amazon-pay-sdk-csharp.git',
#   'ssh_url': 'git@github.com:amzn/amazon-pay-sdk-csharp.git',
#   'clone_url': 'https://github.com/amzn/amazon-pay-sdk-csharp.git',
#   'svn_url': 'https://github.com/amzn/amazon-pay-sdk-csharp',
#   'homepage': 'https://payments.amazon.com/developer',
#   'size': 28264,
#   'stargazers_count': 48,
#   'watchers_count': 48,
#   'language': 'C#',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 40,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 11,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 40,
#   'open_issues': 11,
#   'watchers': 48,
#   'default_branch': 'master'},
#  {'id': 27605347,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNzYwNTM0Nw==',
#   'name': 'amazon-pay-sdk-java',
#   'full_name': 'amzn/amazon-pay-sdk-java',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-pay-sdk-java',
#   'description': ' Amazon Pay Java SDK',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/deployments',
#   'created_at': '2014-12-05T18:51:43Z',
#   'updated_at': '2024-09-09T14:17:34Z',
#   'pushed_at': '2024-08-10T17:28:22Z',
#   'git_url': 'git://github.com/amzn/amazon-pay-sdk-java.git',
#   'ssh_url': 'git@github.com:amzn/amazon-pay-sdk-java.git',
#   'clone_url': 'https://github.com/amzn/amazon-pay-sdk-java.git',
#   'svn_url': 'https://github.com/amzn/amazon-pay-sdk-java',
#   'homepage': 'https://pay.amazon.com/documentation',
#   'size': 13957,
#   'stargazers_count': 58,
#   'watchers_count': 58,
#   'language': 'Java',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 51,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 15,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 51,
#   'open_issues': 15,
#   'watchers': 58,
#   'default_branch': 'master'},
#  {'id': 26331269,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNjMzMTI2OQ==',
#   'name': 'amazon-pay-sdk-php',
#   'full_name': 'amzn/amazon-pay-sdk-php',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-pay-sdk-php',
#   'description': 'Amazon Pay PHP SDK',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/deployments',
#   'created_at': '2014-11-07T18:00:47Z',
#   'updated_at': '2024-09-17T15:30:38Z',
#   'pushed_at': '2024-05-14T13:04:33Z',
#   'git_url': 'git://github.com/amzn/amazon-pay-sdk-php.git',
#   'ssh_url': 'git@github.com:amzn/amazon-pay-sdk-php.git',
#   'clone_url': 'https://github.com/amzn/amazon-pay-sdk-php.git',
#   'svn_url': 'https://github.com/amzn/amazon-pay-sdk-php',
#   'homepage': 'https://pay.amazon.com/documentation',
#   'size': 877,
#   'stargazers_count': 208,
#   'watchers_count': 208,
#   'language': 'PHP',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 91,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 37,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 91,
#   'open_issues': 37,
#   'watchers': 208,
#   'default_branch': 'master'}]

# %%
len(response.json())
# Out:
# 30

# %% [markdown]
# ### Autenticação

# %% [markdown]
# Solicitações autenticadas têm um limite de taxa mais alto. Quando um usuário faz uma solicitação autenticada, ele fornece credenciais que comprovam sua identidade, o que permite que a API confie nele e lhe conceda acesso a recursos e funcionalidades adicionais.
#
# Além disso, a maioria das APIs estabelece limites para o número de solicitações que um usuário pode fazer em um determinado período de tempo, conhecido como 'limite de taxa'. Quando um usuário faz solicitações autenticadas, a API geralmente permite que ele faça mais solicitações em um determinado período de tempo, devido à maior confiança e credibilidade que a autenticação fornece.

# %%
load_dotenv()
access_token = os.getenv("API_TOKEN")
headers = {'Authorization': 'Bearer ' + access_token,
           'X-GitHub-Api-Version': '2022-11-28'}

# %% [markdown]
# ### Paginando os repositórios

# %%
api_base_url = 'https://api.github.com'
owner = 'amzn' #username de onde vai ser coletado os dados
url = f'{api_base_url}/users/{owner}/repos'

url
# Out:
# 'https://api.github.com/users/amzn/repos'

# %%
repos_list = []
for number_page in range(1,7):
    try:
        url_page = f'{url}?page={number_page}'
        response = requests.get(url_page, headers=headers)
        repos_list.append(response.json())
    except:
        repos_list.append(None)

# %%
repos_list
# Out:
# [[{'id': 171339259,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkxNzEzMzkyNTk=',
#    'name': '.github',
#    'full_name': 'amzn/.github',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/.github',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/.github',
#    'forks_url': 'https://api.github.com/repos/amzn/.github/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/.github/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/.github/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/.github/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/.github/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/.github/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/.github/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/.github/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/.github/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/.github/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/.github/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/.github/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/.github/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/.github/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/.github/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/.github/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/.github/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/.github/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/.github/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/.github/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/.github/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/.github/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/.github/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/.github/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/.github/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/.github/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/.github/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/.github/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/.github/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/.github/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/.github/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/.github/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/.github/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/.github/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/.github/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/.github/deployments',
#    'created_at': '2019-02-18T18:59:22Z',
#    'updated_at': '2025-01-23T06:17:33Z',
#    'pushed_at': '2024-10-18T22:23:05Z',
#    'git_url': 'git://github.com/amzn/.github.git',
#    'ssh_url': 'git@github.com:amzn/.github.git',
#    'clone_url': 'https://github.com/amzn/.github.git',
#    'svn_url': 'https://github.com/amzn/.github',
#    'homepage': None,
#    'size': 24,
#    'stargazers_count': 15,
#    'watchers_count': 15,
#    'language': None,
#    'has_issues': True,
#    'has_projects': False,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 367,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 3,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 367,
#    'open_issues': 3,
#    'watchers': 15,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 492978607,
#    'node_id': 'R_kgDOHWJBrw',
#    'name': 'ads-advanced-tools-docs',
#    'full_name': 'amzn/ads-advanced-tools-docs',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/ads-advanced-tools-docs',
#    'description': 'Code samples and supplements for the Amazon Ads advanced tools center',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs',
#    'forks_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/deployments',
#    'created_at': '2022-05-16T19:49:03Z',
#    'updated_at': '2025-02-08T03:06:07Z',
#    'pushed_at': '2025-01-29T14:49:12Z',
#    'git_url': 'git://github.com/amzn/ads-advanced-tools-docs.git',
#    'ssh_url': 'git@github.com:amzn/ads-advanced-tools-docs.git',
#    'clone_url': 'https://github.com/amzn/ads-advanced-tools-docs.git',
#    'svn_url': 'https://github.com/amzn/ads-advanced-tools-docs',
#    'homepage': 'https://advertising.amazon.com/API/docs/en-us/index',
#    'size': 387,
#    'stargazers_count': 105,
#    'watchers_count': 105,
#    'language': 'Jupyter Notebook',
#    'has_issues': True,
#    'has_projects': False,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': True,
#    'forks_count': 35,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 39,
#    'license': {'key': 'mit-0',
#     'name': 'MIT No Attribution',
#     'spdx_id': 'MIT-0',
#     'url': 'https://api.github.com/licenses/mit-0',
#     'node_id': 'MDc6TGljZW5zZTQx'},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': ['amazon', 'amazon-ads-api', 'amazon-marketing-stream'],
#    'visibility': 'public',
#    'forks': 35,
#    'open_issues': 39,
#    'watchers': 105,
#    'default_branch': 'main',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 674005216,
#    'node_id': 'R_kgDOKCyA4A',
#    'name': 'ads-pao-amznjs-gtm-template',
#    'full_name': 'amzn/ads-pao-amznjs-gtm-template',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template',
#    'forks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/deployments',
#    'created_at': '2023-08-02T23:41:56Z',
#    'updated_at': '2024-09-05T08:32:25Z',
#    'pushed_at': '2024-06-03T16:53:23Z',
#    'git_url': 'git://github.com/amzn/ads-pao-amznjs-gtm-template.git',
#    'ssh_url': 'git@github.com:amzn/ads-pao-amznjs-gtm-template.git',
#    'clone_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template.git',
#    'svn_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template',
#    'homepage': None,
#    'size': 165,
#    'stargazers_count': 3,
#    'watchers_count': 3,
#    'language': 'Smarty',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 3,
#    'default_branch': 'main',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 41117941,
#    'node_id': 'MDEwOlJlcG9zaXRvcnk0MTExNzk0MQ==',
#    'name': 'alexa-coho',
#    'full_name': 'amzn/alexa-coho',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/alexa-coho',
#    'description': 'Sample code for building skill adapters for Alexa Connected Home using the Lighting API',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/alexa-coho',
#    'forks_url': 'https://api.github.com/repos/amzn/alexa-coho/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/alexa-coho/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/alexa-coho/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/alexa-coho/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/alexa-coho/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/alexa-coho/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/alexa-coho/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/alexa-coho/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/alexa-coho/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/alexa-coho/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/alexa-coho/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/alexa-coho/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/alexa-coho/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/alexa-coho/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/alexa-coho/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/alexa-coho/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/alexa-coho/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/alexa-coho/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/alexa-coho/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/alexa-coho/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/alexa-coho/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/alexa-coho/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/alexa-coho/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/alexa-coho/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/alexa-coho/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/alexa-coho/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/alexa-coho/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/alexa-coho/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/alexa-coho/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/alexa-coho/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/alexa-coho/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/alexa-coho/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/alexa-coho/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/alexa-coho/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/alexa-coho/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/alexa-coho/deployments',
#    'created_at': '2015-08-20T20:42:31Z',
#    'updated_at': '2024-07-11T01:03:40Z',
#    'pushed_at': '2023-04-01T08:35:29Z',
#    'git_url': 'git://github.com/amzn/alexa-coho.git',
#    'ssh_url': 'git@github.com:amzn/alexa-coho.git',
#    'clone_url': 'https://github.com/amzn/alexa-coho.git',
#    'svn_url': 'https://github.com/amzn/alexa-coho',
#    'homepage': None,
#    'size': 209,
#    'stargazers_count': 63,
#    'watchers_count': 63,
#    'language': 'JavaScript',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 25,
#    'mirror_url': None,
#    'archived': True,
#    'disabled': False,
#    'open_issues_count': 4,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 25,
#    'open_issues': 4,
#    'watchers': 63,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 39471546,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkzOTQ3MTU0Ng==',
#    'name': 'alexa-skills-kit-js',
#    'full_name': 'amzn/alexa-skills-kit-js',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/alexa-skills-kit-js',
#    'description': ' SDK and example code for building voice-enabled skills for the Amazon Echo. ',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js',
#    'forks_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/deployments',
#    'created_at': '2015-07-21T21:46:48Z',
#    'updated_at': '2024-08-04T00:31:19Z',
#    'pushed_at': '2020-10-01T06:10:20Z',
#    'git_url': 'git://github.com/amzn/alexa-skills-kit-js.git',
#    'ssh_url': 'git@github.com:amzn/alexa-skills-kit-js.git',
#    'clone_url': 'https://github.com/amzn/alexa-skills-kit-js.git',
#    'svn_url': 'https://github.com/amzn/alexa-skills-kit-js',
#    'homepage': 'http://developer.amazon.com/ask',
#    'size': 8827,
#    'stargazers_count': 1135,
#    'watchers_count': 1135,
#    'language': None,
#    'has_issues': False,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 1037,
#    'mirror_url': None,
#    'archived': True,
#    'disabled': False,
#    'open_issues_count': 11,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 1037,
#    'open_issues': 11,
#    'watchers': 1135,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 495519526,
#    'node_id': 'R_kgDOHYkHJg',
#    'name': 'amazon-ads-advertiser-audience-normalization-sdk-py',
#    'full_name': 'amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#    'forks_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/deployments',
#    'created_at': '2022-05-23T17:59:56Z',
#    'updated_at': '2025-01-15T02:22:55Z',
#    'pushed_at': '2022-05-23T21:20:34Z',
#    'git_url': 'git://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#    'ssh_url': 'git@github.com:amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#    'clone_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#    'svn_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#    'homepage': None,
#    'size': 16,
#    'stargazers_count': 10,
#    'watchers_count': 10,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 3,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'other',
#     'name': 'Other',
#     'spdx_id': 'NOASSERTION',
#     'url': None,
#     'node_id': 'MDc6TGljZW5zZTA='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 3,
#    'open_issues': 0,
#    'watchers': 10,
#    'default_branch': 'main',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 61315875,
#    'node_id': 'MDEwOlJlcG9zaXRvcnk2MTMxNTg3NQ==',
#    'name': 'amazon-advertising-api-php-sdk',
#    'full_name': 'amzn/amazon-advertising-api-php-sdk',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk',
#    'description': '⛔️ DEPRECATED - Amazon Advertising API PHP Client Library',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk',
#    'forks_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/deployments',
#    'created_at': '2016-06-16T18:16:46Z',
#    'updated_at': '2024-09-14T07:43:36Z',
#    'pushed_at': '2020-09-20T17:25:48Z',
#    'git_url': 'git://github.com/amzn/amazon-advertising-api-php-sdk.git',
#    'ssh_url': 'git@github.com:amzn/amazon-advertising-api-php-sdk.git',
#    'clone_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk.git',
#    'svn_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk',
#    'homepage': '',
#    'size': 49,
#    'stargazers_count': 93,
#    'watchers_count': 93,
#    'language': 'PHP',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 66,
#    'mirror_url': None,
#    'archived': True,
#    'disabled': False,
#    'open_issues_count': 14,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 66,
#    'open_issues': 14,
#    'watchers': 93,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 429297502,
#    'node_id': 'R_kgDOGZaPXg',
#    'name': 'amazon-codeguru-profiler-for-spark',
#    'full_name': 'amzn/amazon-codeguru-profiler-for-spark',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/amazon-codeguru-profiler-for-spark',
#    'description': 'A Spark plugin for CPU and memory profiling',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark',
#    'forks_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/pulls{/number}',
# ...
#    'hooks_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/deployments',
#    'created_at': '2019-10-04T18:00:25Z',
#    'updated_at': '2024-10-12T09:44:31Z',
#    'pushed_at': '2024-05-30T18:55:33Z',
#    'git_url': 'git://github.com/amzn/zeek-plugin-s7comm.git',
#    'ssh_url': 'git@github.com:amzn/zeek-plugin-s7comm.git',
#    'clone_url': 'https://github.com/amzn/zeek-plugin-s7comm.git',
#    'svn_url': 'https://github.com/amzn/zeek-plugin-s7comm',
#    'homepage': None,
#    'size': 36,
#    'stargazers_count': 41,
#    'watchers_count': 41,
#    'language': 'Zeek',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 11,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 1,
#    'license': {'key': 'bsd-3-clause',
#     'name': 'BSD 3-Clause "New" or "Revised" License',
#     'spdx_id': 'BSD-3-Clause',
#     'url': 'https://api.github.com/licenses/bsd-3-clause',
#     'node_id': 'MDc6TGljZW5zZTU='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': ['ics-security', 'security-tools', 'zeek', 'zeek-package'],
#    'visibility': 'public',
#    'forks': 11,
#    'open_issues': 1,
#    'watchers': 41,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 212874433,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkyMTI4NzQ0MzM=',
#    'name': 'zeek-plugin-tds',
#    'full_name': 'amzn/zeek-plugin-tds',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/zeek-plugin-tds',
#    'description': 'Zeek network security monitor plugin that enables parsing of the Tabular Data Stream (TDS) protocol',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/zeek-plugin-tds',
#    'forks_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/deployments',
#    'created_at': '2019-10-04T18:01:45Z',
#    'updated_at': '2024-10-12T09:44:12Z',
#    'pushed_at': '2024-05-30T18:56:04Z',
#    'git_url': 'git://github.com/amzn/zeek-plugin-tds.git',
#    'ssh_url': 'git@github.com:amzn/zeek-plugin-tds.git',
#    'clone_url': 'https://github.com/amzn/zeek-plugin-tds.git',
#    'svn_url': 'https://github.com/amzn/zeek-plugin-tds',
#    'homepage': '',
#    'size': 29,
#    'stargazers_count': 25,
#    'watchers_count': 25,
#    'language': 'Zeek',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 12,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'bsd-3-clause',
#     'name': 'BSD 3-Clause "New" or "Revised" License',
#     'spdx_id': 'BSD-3-Clause',
#     'url': 'https://api.github.com/licenses/bsd-3-clause',
#     'node_id': 'MDc6TGljZW5zZTU='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': ['security-tools', 'zeek', 'zeek-package'],
#    'visibility': 'public',
#    'forks': 12,
#    'open_issues': 0,
#    'watchers': 25,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 361620746,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkzNjE2MjA3NDY=',
#    'name': 'zero-shot-rlhr',
#    'full_name': 'amzn/zero-shot-rlhr',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/zero-shot-rlhr',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/zero-shot-rlhr',
#    'forks_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/deployments',
#    'created_at': '2021-04-26T04:49:11Z',
#    'updated_at': '2024-12-03T08:59:03Z',
#    'pushed_at': '2021-04-26T05:39:00Z',
#    'git_url': 'git://github.com/amzn/zero-shot-rlhr.git',
#    'ssh_url': 'git@github.com:amzn/zero-shot-rlhr.git',
#    'clone_url': 'https://github.com/amzn/zero-shot-rlhr.git',
#    'svn_url': 'https://github.com/amzn/zero-shot-rlhr',
#    'homepage': None,
#    'size': 119,
#    'stargazers_count': 52,
#    'watchers_count': 52,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 16,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 1,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 16,
#    'open_issues': 1,
#    'watchers': 52,
#    'default_branch': 'main',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}}]]

# %%
len(repos_list) #Quantas páginas de repositórios
# Out:
# 6

# %%
len(repos_list[0]) #Repositórios em uma única página
# Out:
# 30

# %% [markdown]
# ## Transformando os dados

# %% [markdown]
# ### Nomes dos repositórios

# %%
repos_list
# Out:
# [[{'id': 171339259,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkxNzEzMzkyNTk=',
#    'name': '.github',
#    'full_name': 'amzn/.github',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/.github',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/.github',
#    'forks_url': 'https://api.github.com/repos/amzn/.github/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/.github/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/.github/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/.github/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/.github/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/.github/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/.github/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/.github/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/.github/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/.github/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/.github/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/.github/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/.github/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/.github/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/.github/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/.github/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/.github/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/.github/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/.github/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/.github/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/.github/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/.github/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/.github/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/.github/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/.github/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/.github/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/.github/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/.github/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/.github/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/.github/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/.github/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/.github/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/.github/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/.github/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/.github/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/.github/deployments',
#    'created_at': '2019-02-18T18:59:22Z',
#    'updated_at': '2025-01-23T06:17:33Z',
#    'pushed_at': '2024-10-18T22:23:05Z',
#    'git_url': 'git://github.com/amzn/.github.git',
#    'ssh_url': 'git@github.com:amzn/.github.git',
#    'clone_url': 'https://github.com/amzn/.github.git',
#    'svn_url': 'https://github.com/amzn/.github',
#    'homepage': None,
#    'size': 24,
#    'stargazers_count': 15,
#    'watchers_count': 15,
#    'language': None,
#    'has_issues': True,
#    'has_projects': False,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 367,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 3,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 367,
#    'open_issues': 3,
#    'watchers': 15,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 492978607,
#    'node_id': 'R_kgDOHWJBrw',
#    'name': 'ads-advanced-tools-docs',
#    'full_name': 'amzn/ads-advanced-tools-docs',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/ads-advanced-tools-docs',
#    'description': 'Code samples and supplements for the Amazon Ads advanced tools center',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs',
#    'forks_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/deployments',
#    'created_at': '2022-05-16T19:49:03Z',
#    'updated_at': '2025-02-08T03:06:07Z',
#    'pushed_at': '2025-01-29T14:49:12Z',
#    'git_url': 'git://github.com/amzn/ads-advanced-tools-docs.git',
#    'ssh_url': 'git@github.com:amzn/ads-advanced-tools-docs.git',
#    'clone_url': 'https://github.com/amzn/ads-advanced-tools-docs.git',
#    'svn_url': 'https://github.com/amzn/ads-advanced-tools-docs',
#    'homepage': 'https://advertising.amazon.com/API/docs/en-us/index',
#    'size': 387,
#    'stargazers_count': 105,
#    'watchers_count': 105,
#    'language': 'Jupyter Notebook',
#    'has_issues': True,
#    'has_projects': False,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': True,
#    'forks_count': 35,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 39,
#    'license': {'key': 'mit-0',
#     'name': 'MIT No Attribution',
#     'spdx_id': 'MIT-0',
#     'url': 'https://api.github.com/licenses/mit-0',
#     'node_id': 'MDc6TGljZW5zZTQx'},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': ['amazon', 'amazon-ads-api', 'amazon-marketing-stream'],
#    'visibility': 'public',
#    'forks': 35,
#    'open_issues': 39,
#    'watchers': 105,
#    'default_branch': 'main',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 674005216,
#    'node_id': 'R_kgDOKCyA4A',
#    'name': 'ads-pao-amznjs-gtm-template',
#    'full_name': 'amzn/ads-pao-amznjs-gtm-template',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template',
#    'forks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/deployments',
#    'created_at': '2023-08-02T23:41:56Z',
#    'updated_at': '2024-09-05T08:32:25Z',
#    'pushed_at': '2024-06-03T16:53:23Z',
#    'git_url': 'git://github.com/amzn/ads-pao-amznjs-gtm-template.git',
#    'ssh_url': 'git@github.com:amzn/ads-pao-amznjs-gtm-template.git',
#    'clone_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template.git',
#    'svn_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template',
#    'homepage': None,
#    'size': 165,
#    'stargazers_count': 3,
#    'watchers_count': 3,
#    'language': 'Smarty',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 3,
#    'default_branch': 'main',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 41117941,
#    'node_id': 'MDEwOlJlcG9zaXRvcnk0MTExNzk0MQ==',
#    'name': 'alexa-coho',
#    'full_name': 'amzn/alexa-coho',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/alexa-coho',
#    'description': 'Sample code for building skill adapters for Alexa Connected Home using the Lighting API',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/alexa-coho',
#    'forks_url': 'https://api.github.com/repos/amzn/alexa-coho/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/alexa-coho/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/alexa-coho/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/alexa-coho/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/alexa-coho/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/alexa-coho/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/alexa-coho/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/alexa-coho/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/alexa-coho/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/alexa-coho/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/alexa-coho/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/alexa-coho/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/alexa-coho/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/alexa-coho/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/alexa-coho/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/alexa-coho/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/alexa-coho/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/alexa-coho/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/alexa-coho/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/alexa-coho/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/alexa-coho/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/alexa-coho/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/alexa-coho/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/alexa-coho/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/alexa-coho/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/alexa-coho/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/alexa-coho/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/alexa-coho/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/alexa-coho/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/alexa-coho/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/alexa-coho/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/alexa-coho/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/alexa-coho/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/alexa-coho/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/alexa-coho/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/alexa-coho/deployments',
#    'created_at': '2015-08-20T20:42:31Z',
#    'updated_at': '2024-07-11T01:03:40Z',
#    'pushed_at': '2023-04-01T08:35:29Z',
#    'git_url': 'git://github.com/amzn/alexa-coho.git',
#    'ssh_url': 'git@github.com:amzn/alexa-coho.git',
#    'clone_url': 'https://github.com/amzn/alexa-coho.git',
#    'svn_url': 'https://github.com/amzn/alexa-coho',
#    'homepage': None,
#    'size': 209,
#    'stargazers_count': 63,
#    'watchers_count': 63,
#    'language': 'JavaScript',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 25,
#    'mirror_url': None,
#    'archived': True,
#    'disabled': False,
#    'open_issues_count': 4,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 25,
#    'open_issues': 4,
#    'watchers': 63,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 39471546,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkzOTQ3MTU0Ng==',
#    'name': 'alexa-skills-kit-js',
#    'full_name': 'amzn/alexa-skills-kit-js',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/alexa-skills-kit-js',
#    'description': ' SDK and example code for building voice-enabled skills for the Amazon Echo. ',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js',
#    'forks_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/deployments',
#    'created_at': '2015-07-21T21:46:48Z',
#    'updated_at': '2024-08-04T00:31:19Z',
#    'pushed_at': '2020-10-01T06:10:20Z',
#    'git_url': 'git://github.com/amzn/alexa-skills-kit-js.git',
#    'ssh_url': 'git@github.com:amzn/alexa-skills-kit-js.git',
#    'clone_url': 'https://github.com/amzn/alexa-skills-kit-js.git',
#    'svn_url': 'https://github.com/amzn/alexa-skills-kit-js',
#    'homepage': 'http://developer.amazon.com/ask',
#    'size': 8827,
#    'stargazers_count': 1135,
#    'watchers_count': 1135,
#    'language': None,
#    'has_issues': False,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 1037,
#    'mirror_url': None,
#    'archived': True,
#    'disabled': False,
#    'open_issues_count': 11,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 1037,
#    'open_issues': 11,
#    'watchers': 1135,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 495519526,
#    'node_id': 'R_kgDOHYkHJg',
#    'name': 'amazon-ads-advertiser-audience-normalization-sdk-py',
#    'full_name': 'amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#    'forks_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/deployments',
#    'created_at': '2022-05-23T17:59:56Z',
#    'updated_at': '2025-01-15T02:22:55Z',
#    'pushed_at': '2022-05-23T21:20:34Z',
#    'git_url': 'git://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#    'ssh_url': 'git@github.com:amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#    'clone_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#    'svn_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#    'homepage': None,
#    'size': 16,
#    'stargazers_count': 10,
#    'watchers_count': 10,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 3,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'other',
#     'name': 'Other',
#     'spdx_id': 'NOASSERTION',
#     'url': None,
#     'node_id': 'MDc6TGljZW5zZTA='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 3,
#    'open_issues': 0,
#    'watchers': 10,
#    'default_branch': 'main',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 61315875,
#    'node_id': 'MDEwOlJlcG9zaXRvcnk2MTMxNTg3NQ==',
#    'name': 'amazon-advertising-api-php-sdk',
#    'full_name': 'amzn/amazon-advertising-api-php-sdk',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk',
#    'description': '⛔️ DEPRECATED - Amazon Advertising API PHP Client Library',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk',
#    'forks_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/deployments',
#    'created_at': '2016-06-16T18:16:46Z',
#    'updated_at': '2024-09-14T07:43:36Z',
#    'pushed_at': '2020-09-20T17:25:48Z',
#    'git_url': 'git://github.com/amzn/amazon-advertising-api-php-sdk.git',
#    'ssh_url': 'git@github.com:amzn/amazon-advertising-api-php-sdk.git',
#    'clone_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk.git',
#    'svn_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk',
#    'homepage': '',
#    'size': 49,
#    'stargazers_count': 93,
#    'watchers_count': 93,
#    'language': 'PHP',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 66,
#    'mirror_url': None,
#    'archived': True,
#    'disabled': False,
#    'open_issues_count': 14,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 66,
#    'open_issues': 14,
#    'watchers': 93,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 429297502,
#    'node_id': 'R_kgDOGZaPXg',
#    'name': 'amazon-codeguru-profiler-for-spark',
#    'full_name': 'amzn/amazon-codeguru-profiler-for-spark',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/amazon-codeguru-profiler-for-spark',
#    'description': 'A Spark plugin for CPU and memory profiling',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark',
#    'forks_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/pulls{/number}',
# ...
#    'hooks_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/zeek-plugin-s7comm/deployments',
#    'created_at': '2019-10-04T18:00:25Z',
#    'updated_at': '2024-10-12T09:44:31Z',
#    'pushed_at': '2024-05-30T18:55:33Z',
#    'git_url': 'git://github.com/amzn/zeek-plugin-s7comm.git',
#    'ssh_url': 'git@github.com:amzn/zeek-plugin-s7comm.git',
#    'clone_url': 'https://github.com/amzn/zeek-plugin-s7comm.git',
#    'svn_url': 'https://github.com/amzn/zeek-plugin-s7comm',
#    'homepage': None,
#    'size': 36,
#    'stargazers_count': 41,
#    'watchers_count': 41,
#    'language': 'Zeek',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 11,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 1,
#    'license': {'key': 'bsd-3-clause',
#     'name': 'BSD 3-Clause "New" or "Revised" License',
#     'spdx_id': 'BSD-3-Clause',
#     'url': 'https://api.github.com/licenses/bsd-3-clause',
#     'node_id': 'MDc6TGljZW5zZTU='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': ['ics-security', 'security-tools', 'zeek', 'zeek-package'],
#    'visibility': 'public',
#    'forks': 11,
#    'open_issues': 1,
#    'watchers': 41,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 212874433,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkyMTI4NzQ0MzM=',
#    'name': 'zeek-plugin-tds',
#    'full_name': 'amzn/zeek-plugin-tds',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/zeek-plugin-tds',
#    'description': 'Zeek network security monitor plugin that enables parsing of the Tabular Data Stream (TDS) protocol',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/zeek-plugin-tds',
#    'forks_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/zeek-plugin-tds/deployments',
#    'created_at': '2019-10-04T18:01:45Z',
#    'updated_at': '2024-10-12T09:44:12Z',
#    'pushed_at': '2024-05-30T18:56:04Z',
#    'git_url': 'git://github.com/amzn/zeek-plugin-tds.git',
#    'ssh_url': 'git@github.com:amzn/zeek-plugin-tds.git',
#    'clone_url': 'https://github.com/amzn/zeek-plugin-tds.git',
#    'svn_url': 'https://github.com/amzn/zeek-plugin-tds',
#    'homepage': '',
#    'size': 29,
#    'stargazers_count': 25,
#    'watchers_count': 25,
#    'language': 'Zeek',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 12,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'bsd-3-clause',
#     'name': 'BSD 3-Clause "New" or "Revised" License',
#     'spdx_id': 'BSD-3-Clause',
#     'url': 'https://api.github.com/licenses/bsd-3-clause',
#     'node_id': 'MDc6TGljZW5zZTU='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': ['security-tools', 'zeek', 'zeek-package'],
#    'visibility': 'public',
#    'forks': 12,
#    'open_issues': 0,
#    'watchers': 25,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 361620746,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkzNjE2MjA3NDY=',
#    'name': 'zero-shot-rlhr',
#    'full_name': 'amzn/zero-shot-rlhr',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/zero-shot-rlhr',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/zero-shot-rlhr',
#    'forks_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/zero-shot-rlhr/deployments',
#    'created_at': '2021-04-26T04:49:11Z',
#    'updated_at': '2024-12-03T08:59:03Z',
#    'pushed_at': '2021-04-26T05:39:00Z',
#    'git_url': 'git://github.com/amzn/zero-shot-rlhr.git',
#    'ssh_url': 'git@github.com:amzn/zero-shot-rlhr.git',
#    'clone_url': 'https://github.com/amzn/zero-shot-rlhr.git',
#    'svn_url': 'https://github.com/amzn/zero-shot-rlhr',
#    'homepage': None,
#    'size': 119,
#    'stargazers_count': 52,
#    'watchers_count': 52,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 16,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 1,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 16,
#    'open_issues': 1,
#    'watchers': 52,
#    'default_branch': 'main',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}}]]

# %%
repos_list[0][3]['name']
# Out:
# 'alexa-coho'

# %%
repos_name =[]
for page in repos_list:
    for repo in page:
        repos_name.append(repo['name'])

# %%
repos_name[10]
# Out:
# 'amazon-hub-counter-api-samples'

# %%
len(repos_name)
# Out:
# 157

# %% [markdown]
# ### Linguagens dos repositórios

# %%
repos_language = []
for page in repos_list:
    for repo in page:
        repos_language.append(repo['language'])

# %%
repos_language
# Out:
# [None,
#  'Jupyter Notebook',
#  'Smarty',
#  'JavaScript',
#  None,
#  'Python',
#  'PHP',
#  'Java',
#  'Python',
#  'CSS',
#  'Java',
#  'Java',
#  'PowerShell',
#  'Java',
#  'C#',
#  'PHP',
#  'Ruby',
#  'JavaScript',
#  'Python',
#  'PHP',
#  'Python',
#  'Jupyter Notebook',
#  'C#',
#  'Java',
#  'JavaScript',
#  'PHP',
#  'Ruby',
#  'C#',
#  'Java',
#  'PHP',
#  'Python',
#  'Ruby',
#  'PHP',
#  'Kotlin',
#  'PHP',
#  'Python',
#  'C',
#  None,
#  'Swift',
#  'Python',
#  'C++',
#  'Python',
#  'Go',
#  'C',
#  'Python',
#  'Python',
#  'Jupyter Notebook',
#  'Python',
#  'Python',
#  None,
#  'Java',
#  'Kotlin',
#  'Python',
#  'Python',
#  'TypeScript',
#  'TypeScript',
#  'Python',
#  None,
#  'Jupyter Notebook',
#  'Python',
#  'Python',
#  'Python',
#  'Java',
#  'Jupyter Notebook',
#  'Python',
#  'Python',
#  'Java',
#  'Objective-C',
#  'JavaScript',
#  'TypeScript',
#  'Java',
#  None,
#  'Python',
#  'Python',
#  'Python',
#  'Java',
#  'Java',
#  'Kotlin',
#  'Java',
#  'C#',
#  'C#',
#  'JavaScript',
#  'JavaScript',
#  'Go',
#  'Java',
#  'TypeScript',
#  'Python',
#  'C++',
#  None,
#  'Python',
#  'Python',
#  'Java',
#  'C#',
#  'HTML',
#  'Kotlin',
#  None,
#  'TypeScript',
#  'PHP',
#  'PHP',
#  None,
#  'JavaScript',
#  'Python',
#  'Scala',
#  'Python',
#  'Python',
#  'Python',
#  'Python',
#  'Python',
#  'Python',
#  'Java',
#  'TypeScript',
#  'Swift',
#  'Python',
#  'TypeScript',
#  'TypeScript',
#  'Ruby',
#  'Python',
#  'Python',
#  'Python',
#  'C',
#  'Python',
#  'Python',
#  'Python',
#  'C++',
#  None,
#  'Mustache',
#  'Java',
#  'Python',
#  'Swift',
#  'JavaScript',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Python',
#  'Python',
#  'Python',
#  'JavaScript',
#  'Python',
#  'TypeScript',
#  'TypeScript',
#  'Python',
#  'Python',
#  'JavaScript',
#  'Python',
#  'Python',
#  'Zeek',
#  'Zeek',
#  'Zeek',
#  'Zeek',
#  'Zeek',
#  'Python']

# %%
len(repos_language)
# Out:
# 157

# %% [markdown]
# ### Criando um DataFrame

# %%
import pandas as pd

# %%
dados_amz = pd.DataFrame()
dados_amz['repository_name'] = repos_name
dados_amz['language'] = repos_language

# %%
dados_amz
# Out:
#                  repository_name          language
# 0                        .github              None
# 1        ads-advanced-tools-docs  Jupyter Notebook
# 2    ads-pao-amznjs-gtm-template            Smarty
# 3                     alexa-coho        JavaScript
# 4            alexa-skills-kit-js              None
# ..                           ...               ...
# 152             zeek-plugin-enip              Zeek
# 153         zeek-plugin-profinet              Zeek
# 154           zeek-plugin-s7comm              Zeek
# 155              zeek-plugin-tds              Zeek
# 156               zero-shot-rlhr            Python
#
# [157 rows x 2 columns]

# %% [markdown]
# Salvando o DataFrame

# %%
dados_amz.to_csv('amazon.csv')

# %% [markdown]
# ## Armazenando os dados

# %% [markdown]
# ### Criando repositório com POST

# %% [markdown]
# ### Formato do arquivo

# %% [markdown]
# ### Upload de arquivo com PUT
